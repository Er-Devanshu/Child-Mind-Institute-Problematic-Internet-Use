# %%
# %%writefile requirements.txt
#
# lightgbm==4.5.0
# xgboost==2.1.1
# scikit-learn==1.4.2
# numpy==1.26.4
# scipy==1.14.0
# Out:
# Writing requirements.txt

# %%
# %%time 

import os
try:
    os.mkdir("/kaggle/working/MLPackages")
except:
    pass

# !pip download -q -r requirements.txt -d /kaggle/working/MLPackages
# Out:
# CPU times: user 221 ms, sys: 49.9 ms, total: 271 ms
# Wall time: 11.7 s

# %%
# %%time 

try:
    os.mkdir("/kaggle/working/PolarsGPU171")
    os.mkdir("/kaggle/working/Polars171")
except:
    pass

# !pip download polars[gpu] --extra-index-url=https://pypi.nvidia.com -d /kaggle/working/PolarsGPU171
# !pip download polars==1.7.1 -d /kaggle/working/Polars171
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.8/517.8 MB 3.0 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.5/32.5 MB 46.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 61.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 MB 12.1 MB/s eta 0:00:0000:01:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 80.2 MB/s eta 0:00:00:00:01
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...

# %%
# !ls
# %reset -f
# Out:
# MLPackages  Polars171  PolarsGPU171  requirements.txt
